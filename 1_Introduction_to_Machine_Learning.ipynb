# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In what scenarios might unsupervised learning provide more insights than supervised learning?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# What are some real-world applications where supervised learning is preferred over unsupervised learning?
#
#
# ![image.png](data:image/png;base64,...)
