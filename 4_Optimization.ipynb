# %% [markdown]
# **Gradient**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Ask Babu to explain this**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
